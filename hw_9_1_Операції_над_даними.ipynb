# %% [markdown]
# <a href="https://colab.research.google.com/github/Olga260584/Python/blob/main/hw_9_1_%D0%9E%D0%BF%D0%B5%D1%80%D0%B0%D1%86%D1%96%D1%97_%D0%BD%D0%B0%D0%B4_%D0%B4%D0%B0%D0%BD%D0%B8%D0%BC%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 101
b = 210
c = 111
d = 402

result = ((a + b) * c) / d

print(result)
# Out:
# 85.8731343283582

# %%
11283 % 89
# Out:
# 69

# %%
11283 // 89
# Out:
# 126

# %%
name = "Olga"

# %%
surname = "Borieish"

# %%
name_surname = name + " " + surname
print(name_surname)
# Out:
# Olga Borieish

# %%
name_surname.upper()
# Out:
# 'OLGA BORIEISH'

# %%
name_surname[2]
# Out:
# 'g'

# %%
print(surname[0], surname[-1])
# Out:
# B h

# %%
len(surname)
# Out:
# 8

# %%
city = "Antananarivo"
city.lower().count("a")
# Out:
# 4

# %%
my_string = "The quick brown fox jumps over the lazy dog!!!"

print(my_string.startswith("The"))
print(my_string.endswith("dog!"))
# Out:
# True
# False

# %%
words = my_string.split()
result = "_".join(words)
print(result)
# Out:
# The_quick_brown_fox_jumps_over_the_lazy_dog!!!
