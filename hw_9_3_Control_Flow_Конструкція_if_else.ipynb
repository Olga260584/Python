# %% [markdown]
# <a href="https://colab.research.google.com/github/Olga260584/Python/blob/main/hw_9_3_Control_Flow_%D0%9A%D0%BE%D0%BD%D1%81%D1%82%D1%80%D1%83%D0%BA%D1%86%D1%96%D1%8F_if_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
temperature = 20

# %%
temperature = 20

if temperature > 25:
    print("Це теплий день.")
elif temperature >= 15:
    print("Це приємний день.")
else:
    print("Це холодний день.")
# Out:
# Це приємний день.

# %%
score = 75

# %%
if score >= 90:
    print("A")
elif score >= 80:
    print("B")
elif score >= 70:
    print("C")
elif score >= 60:
    print("D")
else:
    print("F")
# Out:
# C

# %%
year = 2024

# %%
if (year % 4 == 0 and year % 100 != 0) or year % 400 == 0:
    print("Високосний рік")
else:
    print("Не високосний рік")
# Out:
# Високосний рік
