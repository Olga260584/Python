# %% [markdown]
# <a href="https://colab.research.google.com/github/Olga260584/Python/blob/main/hw_9_3_%D0%A6%D0%B8%D0%BA%D0%BB_while.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
limit = 9

# %%
number = 1

while number <= limit:
    print(number)
    number = number + 1

print("Кінець розрахунку!")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# Кінець розрахунку!

# %%
start = 7

# %%
number = start + 1

while number % 2 != 0:
    number = number + 1

print(number)
# Out:
# 8

# %%
num = 5
factorial = 1
i = 1

while i <= num:
    factorial = factorial * i
    i = i + 1

print(factorial)
# Out:
# 120
