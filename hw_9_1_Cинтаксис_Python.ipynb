# %% [markdown]
# <a href="https://colab.research.google.com/github/Olga260584/Python/blob/main/hw_9_1_C%D0%B8%D0%BD%D1%82%D0%B0%D0%BA%D1%81%D0%B8%D1%81_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
apples = 5
print(apples)
# Out:
# 5

# %%
type(apples)
# Out:
# int

# %%
print(apples + 12)
# Out:
# 17

# %%
a = 48
b = 3

# %%
c = a / b

# %%
print(a, type(a))
print(b, type(b))
print(c, type(c))
# Out:
# 48 <class 'int'>
# 3 <class 'int'>
# 16.0 <class 'float'>

# %%
a = 10
# a = 12
# a = 15

b = 4
# b = 8
# b = 14

c = 3
# c = 6
# c = 9

a + b + c
# Out:
# 17
